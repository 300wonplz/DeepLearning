# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset
from torchvision import datasets, transforms
import torchvision.utils as vutils
from sklearn.model_selection import train_test_split

import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
import time

# %%
def get_noise(batch_size, n_noise):
    return np.random.uniform(-1, 1, (batch_size, n_noise))

# %%
n_noise = 100
n_channel = 3
batch_size = 100

# %%
transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize(mean=(0.5,0.5,0.5),std=(0.5,0.5,0.5))
    ])

# %%
trainset = datasets.STL10(root='../../datasets/STL10', split='train', download=True, transform=transform)
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

# testset = datasets.STL10(root='../../datasets/STL10', split='test', download=True, transform=transform)
# test_loader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified

# %%
class Generator(nn.Module):
    
    def __init__(self):
        super(Generator, self).__init__()
        
        # 1, 100
        self.fc1 = nn.Linear(n_noise, 256*6*6)
            
        self.conv = nn.Sequential(
            nn.ConvTranspose2d(256, 128, 3, 2, 1, output_padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            
            nn.ConvTranspose2d(128, 64, 3, 2, 1, output_padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            
            nn.ConvTranspose2d(64, 32, 3, 2, 1, output_padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            
            nn.ConvTranspose2d(32, 16, 3, 2, 1, output_padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
        
            nn.ConvTranspose2d(16, n_channel, 3, 1, 1)
        )
        
    def forward(self, x):
        x = self.fc1(x)
        x = x.reshape(-1, 256, 6, 6)
        x = self.conv(x)
        return F.tanh(x)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(n_channel, 8, 3, 1, 1),
            nn.LeakyReLU(0.2),
            nn.MaxPool2d(2,2),
            
            nn.Conv2d(8, 16, 3, 1, 1),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            
            nn.Conv2d(16, 32, 3, 1, 1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.MaxPool2d(2,2),
            
            nn.Conv2d(32, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),
            
            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.MaxPool2d(2,2),
            
            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.MaxPool2d(2,2),
            

            nn.Conv2d(256, 256, 3, 1, 1)       
        )
        
        self.fc1 = nn.Linear(256*6*6, 1)
        
    def forward(self, x):
        x = self.conv(x).reshape(-1, 256*6*6)
        x = self.fc1(x)
        
        return F.sigmoid(x)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

G = Generator()
D = Discriminator()

G = G.to(device)
D = D.to(device)

criterion = nn.BCELoss()
optimizerG = optim.Adam(G.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizerD = optim.Adam(D.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %%
print("Training start")
start = time.time()

for epoch in range(400):
    for data, target in train_loader:
        G.train()
        train_x, train_y = data.reshape(-1, 3, 96, 96).to(device), data.to(device)
        train_x = train_x
        
        #training Discriminator
        optimizerD.zero_grad()
        d_real_data = train_x.to(device)
        d_real_output = D(d_real_data)
        d_real_error = criterion(d_real_output, torch.ones(batch_size).reshape(batch_size,1).to(device))
        
        d_gen_input = torch.from_numpy(get_noise(batch_size, n_noise)).float().to(device)
        d_fake_data = G(d_gen_input.float()).detach()
        d_fake_output = D(d_fake_data)
        d_fake_error = criterion(d_fake_output, torch.zeros(batch_size).reshape(batch_size,1).to(device))

        d_train_loss = d_real_error + d_fake_error
        d_train_loss.backward()
        optimizerD.step()
        
        
        #training Generator
        optimizerG.zero_grad()
#         g_data = torch.from_numpy(get_noise(batch_size, n_noise)).float().to(device)
        g_fake_output = G(d_gen_input)
        gd_fake_output = D(g_fake_output)
        g_error = criterion(gd_fake_output, torch.ones(batch_size).reshape(batch_size,1).to(device))
        g_error.backward()
        
        optimizerG.step()
    
    
        lossD = d_train_loss
        lossG = g_error
        
    G.eval()
    print('epoch %d'%epoch, 'lossD',lossD.data,'lossG',lossG.data)
    image = G(torch.from_numpy(get_noise(10, n_noise)).to(device).float())
    fig, ax = plt.subplots(1, 10, figsize=(15,4))
    
    for i in range(10):
        data = image[i].cpu().data.numpy().reshape(3, 96, 96)
        data = np.transpose(data, (1,2,0))
        ax[i].set_axis_off()
        ax[i].imshow((data+1)/2)
    
    plt.savefig('./DCGAN_pytorch_STL10_samples/{}.png'.format(str(epoch).zfill(3)), bbox_inches='tight')
    plt.close()
        
end = time.time()

print('Elapsed Time : %.3f sec'%(end-start))
# Out:
# Training start
# C:\Users\my\Anaconda3\envs\pytorch\lib\site-packages\torch\nn\functional.py:1332: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# C:\Users\my\Anaconda3\envs\pytorch\lib\site-packages\torch\nn\functional.py:1320: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# epoch 0 lossD tensor(0.0315, device='cuda:0') lossG tensor(7.1699, device='cuda:0')
# epoch 1 lossD tensor(0.0213, device='cuda:0') lossG tensor(5.5817, device='cuda:0')
# epoch 2 lossD tensor(0.0430, device='cuda:0') lossG tensor(6.5105, device='cuda:0')
# epoch 3 lossD tensor(0.1079, device='cuda:0') lossG tensor(3.5172, device='cuda:0')
# epoch 4 lossD tensor(0.0813, device='cuda:0') lossG tensor(4.9740, device='cuda:0')
# epoch 5 lossD tensor(0.0793, device='cuda:0') lossG tensor(4.4889, device='cuda:0')
# epoch 6 lossD tensor(0.1810, device='cuda:0') lossG tensor(3.7739, device='cuda:0')
# epoch 7 lossD tensor(0.1385, device='cuda:0') lossG tensor(2.2141, device='cuda:0')
# epoch 8 lossD tensor(0.1137, device='cuda:0') lossG tensor(4.7529, device='cuda:0')
# epoch 9 lossD tensor(0.2479, device='cuda:0') lossG tensor(2.7606, device='cuda:0')
# epoch 10 lossD tensor(0.1946, device='cuda:0') lossG tensor(3.8954, device='cuda:0')
# epoch 11 lossD tensor(0.6504, device='cuda:0') lossG tensor(0.3066, device='cuda:0')
# epoch 12 lossD tensor(0.2716, device='cuda:0') lossG tensor(3.3449, device='cuda:0')
# epoch 13 lossD tensor(0.2676, device='cuda:0') lossG tensor(2.7688, device='cuda:0')
# epoch 14 lossD tensor(0.2128, device='cuda:0') lossG tensor(3.9185, device='cuda:0')
# epoch 15 lossD tensor(0.3204, device='cuda:0') lossG tensor(4.0865, device='cuda:0')
# epoch 16 lossD tensor(0.9468, device='cuda:0') lossG tensor(3.1680, device='cuda:0')
# epoch 17 lossD tensor(0.2529, device='cuda:0') lossG tensor(4.1361, device='cuda:0')
# epoch 18 lossD tensor(0.2182, device='cuda:0') lossG tensor(4.6771, device='cuda:0')
# epoch 19 lossD tensor(0.2277, device='cuda:0') lossG tensor(3.0117, device='cuda:0')
# epoch 20 lossD tensor(0.3054, device='cuda:0') lossG tensor(1.9761, device='cuda:0')
# epoch 21 lossD tensor(0.1548, device='cuda:0') lossG tensor(4.6398, device='cuda:0')
# epoch 22 lossD tensor(0.1490, device='cuda:0') lossG tensor(4.6903, device='cuda:0')
# epoch 23 lossD tensor(0.1059, device='cuda:0') lossG tensor(4.3081, device='cuda:0')
# epoch 24 lossD tensor(0.2258, device='cuda:0') lossG tensor(3.2813, device='cuda:0')
# epoch 25 lossD tensor(0.1468, device='cuda:0') lossG tensor(3.8025, device='cuda:0')
# epoch 26 lossD tensor(0.2902, device='cuda:0') lossG tensor(4.5406, device='cuda:0')
# epoch 27 lossD tensor(0.2258, device='cuda:0') lossG tensor(4.1363, device='cuda:0')
# epoch 28 lossD tensor(0.2722, device='cuda:0') lossG tensor(3.6285, device='cuda:0')
# epoch 29 lossD tensor(0.2172, device='cuda:0') lossG tensor(4.5632, device='cuda:0')
# epoch 30 lossD tensor(0.2978, device='cuda:0') lossG tensor(2.8768, device='cuda:0')
# epoch 31 lossD tensor(0.1983, device='cuda:0') lossG tensor(3.1934, device='cuda:0')
# epoch 32 lossD tensor(0.1176, device='cuda:0') lossG tensor(4.5511, device='cuda:0')
# epoch 33 lossD tensor(0.1828, device='cuda:0') lossG tensor(4.2989, device='cuda:0')
# epoch 34 lossD tensor(0.1701, device='cuda:0') lossG tensor(3.8430, device='cuda:0')
# epoch 35 lossD tensor(1.2479, device='cuda:0') lossG tensor(0.8891, device='cuda:0')
# epoch 36 lossD tensor(0.1737, device='cuda:0') lossG tensor(3.9285, device='cuda:0')
# epoch 37 lossD tensor(0.2360, device='cuda:0') lossG tensor(4.9644, device='cuda:0')
# epoch 38 lossD tensor(0.3477, device='cuda:0') lossG tensor(5.1166, device='cuda:0')
# epoch 39 lossD tensor(0.1395, device='cuda:0') lossG tensor(4.1688, device='cuda:0')
# epoch 40 lossD tensor(0.2303, device='cuda:0') lossG tensor(4.5519, device='cuda:0')
# epoch 41 lossD tensor(0.1040, device='cuda:0') lossG tensor(3.8936, device='cuda:0')
# epoch 42 lossD tensor(0.2734, device='cuda:0') lossG tensor(3.1567, device='cuda:0')
# epoch 43 lossD tensor(0.1428, device='cuda:0') lossG tensor(6.5509, device='cuda:0')
# epoch 44 lossD tensor(0.3733, device='cuda:0') lossG tensor(7.5013, device='cuda:0')
# epoch 45 lossD tensor(0.3722, device='cuda:0') lossG tensor(5.0128, device='cuda:0')
# epoch 46 lossD tensor(0.0626, device='cuda:0') lossG tensor(5.0258, device='cuda:0')
# epoch 47 lossD tensor(0.5303, device='cuda:0') lossG tensor(3.2489, device='cuda:0')
# epoch 48 lossD tensor(1.7763, device='cuda:0') lossG tensor(10.7103, device='cuda:0')
# epoch 49 lossD tensor(0.2759, device='cuda:0') lossG tensor(2.7501, device='cuda:0')
# epoch 50 lossD tensor(0.6084, device='cuda:0') lossG tensor(3.4121, device='cuda:0')
# epoch 51 lossD tensor(4.0861, device='cuda:0') lossG tensor(0.4238, device='cuda:0')
# epoch 52 lossD tensor(0.2548, device='cuda:0') lossG tensor(3.1406, device='cuda:0')
# epoch 53 lossD tensor(0.1650, device='cuda:0') lossG tensor(5.6646, device='cuda:0')
# epoch 54 lossD tensor(0.1466, device='cuda:0') lossG tensor(5.4760, device='cuda:0')
# epoch 55 lossD tensor(0.1022, device='cuda:0') lossG tensor(3.0946, device='cuda:0')
# epoch 56 lossD tensor(0.2200, device='cuda:0') lossG tensor(5.1960, device='cuda:0')
# epoch 57 lossD tensor(0.3329, device='cuda:0') lossG tensor(1.6131, device='cuda:0')
# epoch 58 lossD tensor(0.4511, device='cuda:0') lossG tensor(6.3047, device='cuda:0')
# epoch 59 lossD tensor(0.3503, device='cuda:0') lossG tensor(5.7598, device='cuda:0')
# epoch 60 lossD tensor(0.4518, device='cuda:0') lossG tensor(6.6611, device='cuda:0')
# epoch 61 lossD tensor(0.2358, device='cuda:0') lossG tensor(3.8094, device='cuda:0')
# epoch 62 lossD tensor(1.3045, device='cuda:0') lossG tensor(1.5097, device='cuda:0')
# epoch 63 lossD tensor(0.3180, device='cuda:0') lossG tensor(2.4753, device='cuda:0')
# epoch 64 lossD tensor(0.9905, device='cuda:0') lossG tensor(10.6187, device='cuda:0')
# epoch 65 lossD tensor(0.9643, device='cuda:0') lossG tensor(9.9003, device='cuda:0')
# epoch 66 lossD tensor(0.3976, device='cuda:0') lossG tensor(7.9104, device='cuda:0')
# epoch 67 lossD tensor(0.1500, device='cuda:0') lossG tensor(4.3856, device='cuda:0')
# epoch 68 lossD tensor(0.4740, device='cuda:0') lossG tensor(7.0184, device='cuda:0')
# epoch 69 lossD tensor(0.0936, device='cuda:0') lossG tensor(4.7179, device='cuda:0')
# epoch 70 lossD tensor(0.1307, device='cuda:0') lossG tensor(6.8625, device='cuda:0')
# epoch 71 lossD tensor(0.0847, device='cuda:0') lossG tensor(6.8787, device='cuda:0')
# epoch 72 lossD tensor(0.2495, device='cuda:0') lossG tensor(3.4959, device='cuda:0')
# epoch 73 lossD tensor(0.0846, device='cuda:0') lossG tensor(4.8881, device='cuda:0')
# epoch 74 lossD tensor(0.1174, device='cuda:0') lossG tensor(4.1317, device='cuda:0')
# epoch 75 lossD tensor(0.4110, device='cuda:0') lossG tensor(10.0321, device='cuda:0')
# epoch 76 lossD tensor(0.0727, device='cuda:0') lossG tensor(6.2100, device='cuda:0')
# epoch 77 lossD tensor(0.0815, device='cuda:0') lossG tensor(5.2110, device='cuda:0')
# epoch 78 lossD tensor(0.1596, device='cuda:0') lossG tensor(5.9476, device='cuda:0')
# epoch 79 lossD tensor(0.3365, device='cuda:0') lossG tensor(5.7247, device='cuda:0')
# epoch 80 lossD tensor(0.2460, device='cuda:0') lossG tensor(3.4440, device='cuda:0')
# epoch 81 lossD tensor(4.3387, device='cuda:0') lossG tensor(3.7521, device='cuda:0')
# epoch 82 lossD tensor(0.3424, device='cuda:0') lossG tensor(2.3663, device='cuda:0')
# epoch 83 lossD tensor(0.1073, device='cuda:0') lossG tensor(5.4695, device='cuda:0')
# epoch 84 lossD tensor(0.2140, device='cuda:0') lossG tensor(4.2307, device='cuda:0')
# epoch 85 lossD tensor(0.0828, device='cuda:0') lossG tensor(5.6086, device='cuda:0')
# epoch 86 lossD tensor(0.0503, device='cuda:0') lossG tensor(5.2947, device='cuda:0')
# epoch 87 lossD tensor(0.1880, device='cuda:0') lossG tensor(4.0858, device='cuda:0')
# epoch 88 lossD tensor(0.1358, device='cuda:0') lossG tensor(4.9766, device='cuda:0')
# epoch 89 lossD tensor(0.1100, device='cuda:0') lossG tensor(5.2250, device='cuda:0')
# epoch 90 lossD tensor(0.1047, device='cuda:0') lossG tensor(5.5374, device='cuda:0')
# epoch 91 lossD tensor(0.0834, device='cuda:0') lossG tensor(5.6519, device='cuda:0')
# epoch 92 lossD tensor(0.0589, device='cuda:0') lossG tensor(6.3450, device='cuda:0')
# epoch 93 lossD tensor(0.2583, device='cuda:0') lossG tensor(3.4051, device='cuda:0')
# epoch 94 lossD tensor(0.0629, device='cuda:0') lossG tensor(6.0262, device='cuda:0')
# epoch 95 lossD tensor(0.0670, device='cuda:0') lossG tensor(7.6059, device='cuda:0')
# epoch 96 lossD tensor(0.0612, device='cuda:0') lossG tensor(5.2953, device='cuda:0')
# epoch 97 lossD tensor(0.1964, device='cuda:0') lossG tensor(4.3809, device='cuda:0')
# epoch 98 lossD tensor(0.3297, device='cuda:0') lossG tensor(7.3670, device='cuda:0')
# epoch 99 lossD tensor(0.0953, device='cuda:0') lossG tensor(5.7259, device='cuda:0')
# epoch 100 lossD tensor(0.0866, device='cuda:0') lossG tensor(6.3362, device='cuda:0')
# epoch 101 lossD tensor(0.0681, device='cuda:0') lossG tensor(5.7181, device='cuda:0')
# epoch 102 lossD tensor(0.9207, device='cuda:0') lossG tensor(9.5427, device='cuda:0')
# epoch 103 lossD tensor(0.1474, device='cuda:0') lossG tensor(4.9097, device='cuda:0')
# epoch 104 lossD tensor(0.0656, device='cuda:0') lossG tensor(4.9653, device='cuda:0')
# epoch 105 lossD tensor(0.0611, device='cuda:0') lossG tensor(6.4188, device='cuda:0')
# epoch 106 lossD tensor(0.1851, device='cuda:0') lossG tensor(4.6100, device='cuda:0')
# epoch 107 lossD tensor(0.0292, device='cuda:0') lossG tensor(6.9696, device='cuda:0')
# epoch 108 lossD tensor(0.2350, device='cuda:0') lossG tensor(6.3468, device='cuda:0')
# epoch 109 lossD tensor(0.0624, device='cuda:0') lossG tensor(6.4140, device='cuda:0')
# epoch 110 lossD tensor(0.1603, device='cuda:0') lossG tensor(4.1094, device='cuda:0')
# epoch 111 lossD tensor(0.1903, device='cuda:0') lossG tensor(4.3933, device='cuda:0')
# epoch 112 lossD tensor(0.0921, device='cuda:0') lossG tensor(5.5801, device='cuda:0')
# epoch 113 lossD tensor(0.0320, device='cuda:0') lossG tensor(6.5316, device='cuda:0')
# epoch 114 lossD tensor(0.1357, device='cuda:0') lossG tensor(8.5955, device='cuda:0')
# epoch 115 lossD tensor(0.0440, device='cuda:0') lossG tensor(7.2532, device='cuda:0')
# epoch 116 lossD tensor(0.1022, device='cuda:0') lossG tensor(5.4808, device='cuda:0')
# epoch 117 lossD tensor(0.0808, device='cuda:0') lossG tensor(5.4659, device='cuda:0')
# epoch 118 lossD tensor(0.1734, device='cuda:0') lossG tensor(6.5824, device='cuda:0')
# epoch 119 lossD tensor(0.0889, device='cuda:0') lossG tensor(5.6327, device='cuda:0')
# epoch 120 lossD tensor(0.0237, device='cuda:0') lossG tensor(7.7010, device='cuda:0')
# epoch 121 lossD tensor(0.1429, device='cuda:0') lossG tensor(7.4237, device='cuda:0')
# epoch 122 lossD tensor(0.2639, device='cuda:0') lossG tensor(3.6218, device='cuda:0')
# epoch 123 lossD tensor(0.0479, device='cuda:0') lossG tensor(5.2689, device='cuda:0')
# epoch 124 lossD tensor(0.1077, device='cuda:0') lossG tensor(6.4462, device='cuda:0')
# epoch 125 lossD tensor(0.0425, device='cuda:0') lossG tensor(6.1848, device='cuda:0')
# epoch 126 lossD tensor(0.0723, device='cuda:0') lossG tensor(7.1395, device='cuda:0')
# epoch 127 lossD tensor(0.3087, device='cuda:0') lossG tensor(4.0719, device='cuda:0')
# epoch 128 lossD tensor(0.0518, device='cuda:0') lossG tensor(6.6726, device='cuda:0')
# epoch 129 lossD tensor(0.1008, device='cuda:0') lossG tensor(6.1299, device='cuda:0')
# epoch 130 lossD tensor(0.0381, device='cuda:0') lossG tensor(6.7634, device='cuda:0')
# epoch 131 lossD tensor(1.6597, device='cuda:0') lossG tensor(9.5300e-05, device='cuda:0')
# epoch 132 lossD tensor(0.1105, device='cuda:0') lossG tensor(6.3698, device='cuda:0')
# epoch 133 lossD tensor(0.0761, device='cuda:0') lossG tensor(6.5033, device='cuda:0')
# epoch 134 lossD tensor(5.1982, device='cuda:0') lossG tensor(0.0187, device='cuda:0')
# epoch 135 lossD tensor(0.1819, device='cuda:0') lossG tensor(4.4286, device='cuda:0')
# epoch 136 lossD tensor(0.1030, device='cuda:0') lossG tensor(4.8816, device='cuda:0')
# epoch 137 lossD tensor(0.0620, device='cuda:0') lossG tensor(6.1921, device='cuda:0')
# epoch 138 lossD tensor(0.0922, device='cuda:0') lossG tensor(6.9004, device='cuda:0')
# epoch 139 lossD tensor(0.0812, device='cuda:0') lossG tensor(5.5647, device='cuda:0')
# epoch 140 lossD tensor(0.2422, device='cuda:0') lossG tensor(5.7947, device='cuda:0')
# epoch 141 lossD tensor(0.0632, device='cuda:0') lossG tensor(5.7943, device='cuda:0')
# epoch 142 lossD tensor(0.0363, device='cuda:0') lossG tensor(6.1614, device='cuda:0')
# epoch 143 lossD tensor(0.0485, device='cuda:0') lossG tensor(8.1973, device='cuda:0')
# epoch 144 lossD tensor(0.0718, device='cuda:0') lossG tensor(5.5850, device='cuda:0')
# epoch 145 lossD tensor(0.0343, device='cuda:0') lossG tensor(6.5261, device='cuda:0')
# epoch 146 lossD tensor(0.0218, device='cuda:0') lossG tensor(9.1027, device='cuda:0')
# epoch 147 lossD tensor(0.2256, device='cuda:0') lossG tensor(4.8471, device='cuda:0')
# epoch 148 lossD tensor(0.1163, device='cuda:0') lossG tensor(5.5867, device='cuda:0')
# epoch 149 lossD tensor(0.0886, device='cuda:0') lossG tensor(6.7062, device='cuda:0')
# epoch 150 lossD tensor(0.0522, device='cuda:0') lossG tensor(8.1290, device='cuda:0')
# epoch 151 lossD tensor(0.0475, device='cuda:0') lossG tensor(5.6436, device='cuda:0')
# epoch 152 lossD tensor(0.0360, device='cuda:0') lossG tensor(6.8169, device='cuda:0')
# epoch 153 lossD tensor(0.0219, device='cuda:0') lossG tensor(8.1765, device='cuda:0')
# epoch 154 lossD tensor(0.5177, device='cuda:0') lossG tensor(3.6865, device='cuda:0')
# epoch 155 lossD tensor(0.1193, device='cuda:0') lossG tensor(5.7946, device='cuda:0')
# epoch 156 lossD tensor(0.1043, device='cuda:0') lossG tensor(6.3696, device='cuda:0')
# epoch 157 lossD tensor(0.0744, device='cuda:0') lossG tensor(6.2804, device='cuda:0')
# epoch 158 lossD tensor(0.0352, device='cuda:0') lossG tensor(6.9723, device='cuda:0')
# epoch 159 lossD tensor(0.0454, device='cuda:0') lossG tensor(6.6349, device='cuda:0')
# epoch 160 lossD tensor(2.0714, device='cuda:0') lossG tensor(4.4269, device='cuda:0')
# epoch 161 lossD tensor(0.2100, device='cuda:0') lossG tensor(4.6496, device='cuda:0')
# epoch 162 lossD tensor(0.0588, device='cuda:0') lossG tensor(6.9244, device='cuda:0')
# epoch 163 lossD tensor(0.0436, device='cuda:0') lossG tensor(6.4246, device='cuda:0')
# epoch 164 lossD tensor(0.1074, device='cuda:0') lossG tensor(7.0110, device='cuda:0')
# epoch 165 lossD tensor(0.0880, device='cuda:0') lossG tensor(6.5125, device='cuda:0')
# epoch 166 lossD tensor(0.0919, device='cuda:0') lossG tensor(5.9583, device='cuda:0')
# epoch 167 lossD tensor(0.0425, device='cuda:0') lossG tensor(7.1330, device='cuda:0')
# epoch 168 lossD tensor(0.0926, device='cuda:0') lossG tensor(5.7400, device='cuda:0')
# epoch 169 lossD tensor(0.1173, device='cuda:0') lossG tensor(8.0247, device='cuda:0')
# epoch 170 lossD tensor(0.0577, device='cuda:0') lossG tensor(7.0044, device='cuda:0')
# epoch 171 lossD tensor(0.0518, device='cuda:0') lossG tensor(6.3952, device='cuda:0')
# epoch 172 lossD tensor(12.8613, device='cuda:0') lossG tensor(0.0176, device='cuda:0')
# epoch 173 lossD tensor(0.0737, device='cuda:0') lossG tensor(6.0728, device='cuda:0')
# epoch 174 lossD tensor(0.0777, device='cuda:0') lossG tensor(5.3499, device='cuda:0')
# epoch 175 lossD tensor(0.0332, device='cuda:0') lossG tensor(8.0008, device='cuda:0')
# epoch 176 lossD tensor(0.0388, device='cuda:0') lossG tensor(6.4061, device='cuda:0')
# epoch 177 lossD tensor(0.1295, device='cuda:0') lossG tensor(6.2215, device='cuda:0')
# epoch 178 lossD tensor(0.0706, device='cuda:0') lossG tensor(6.2655, device='cuda:0')
# epoch 179 lossD tensor(0.0787, device='cuda:0') lossG tensor(5.5555, device='cuda:0')
# epoch 180 lossD tensor(0.0732, device='cuda:0') lossG tensor(6.4794, device='cuda:0')
# epoch 181 lossD tensor(0.0151, device='cuda:0') lossG tensor(7.8611, device='cuda:0')
# epoch 182 lossD tensor(0.0579, device='cuda:0') lossG tensor(7.7189, device='cuda:0')
# epoch 183 lossD tensor(0.0266, device='cuda:0') lossG tensor(9.3797, device='cuda:0')
# epoch 184 lossD tensor(0.1756, device='cuda:0') lossG tensor(5.3498, device='cuda:0')
# epoch 185 lossD tensor(0.0680, device='cuda:0') lossG tensor(7.1048, device='cuda:0')
# epoch 186 lossD tensor(0.0330, device='cuda:0') lossG tensor(6.5576, device='cuda:0')
# epoch 187 lossD tensor(0.0291, device='cuda:0') lossG tensor(7.4209, device='cuda:0')
# epoch 188 lossD tensor(0.0199, device='cuda:0') lossG tensor(9.0885, device='cuda:0')
# epoch 189 lossD tensor(0.0278, device='cuda:0') lossG tensor(7.0209, device='cuda:0')
# epoch 190 lossD tensor(0.0128, device='cuda:0') lossG tensor(7.5204, device='cuda:0')
# epoch 191 lossD tensor(0.0469, device='cuda:0') lossG tensor(6.9850, device='cuda:0')
# epoch 192 lossD tensor(0.8504, device='cuda:0') lossG tensor(11.4003, device='cuda:0')
# epoch 193 lossD tensor(0.2195, device='cuda:0') lossG tensor(5.7062, device='cuda:0')
# epoch 194 lossD tensor(0.1119, device='cuda:0') lossG tensor(4.5458, device='cuda:0')
# epoch 195 lossD tensor(0.1049, device='cuda:0') lossG tensor(6.0889, device='cuda:0')
# epoch 196 lossD tensor(2.1778, device='cuda:0') lossG tensor(0.2757, device='cuda:0')
# epoch 197 lossD tensor(0.1364, device='cuda:0') lossG tensor(5.1197, device='cuda:0')
# epoch 198 lossD tensor(0.0251, device='cuda:0') lossG tensor(6.8112, device='cuda:0')
# epoch 199 lossD tensor(0.0585, device='cuda:0') lossG tensor(6.2466, device='cuda:0')
# epoch 200 lossD tensor(0.0183, device='cuda:0') lossG tensor(8.6981, device='cuda:0')
# epoch 201 lossD tensor(0.0737, device='cuda:0') lossG tensor(7.4449, device='cuda:0')
# epoch 202 lossD tensor(0.0143, device='cuda:0') lossG tensor(6.7357, device='cuda:0')
# epoch 203 lossD tensor(0.1541, device='cuda:0') lossG tensor(6.1398, device='cuda:0')
# epoch 204 lossD tensor(0.0581, device='cuda:0') lossG tensor(8.4124, device='cuda:0')
# epoch 205 lossD tensor(0.0660, device='cuda:0') lossG tensor(6.8123, device='cuda:0')
# epoch 206 lossD tensor(0.0349, device='cuda:0') lossG tensor(8.1375, device='cuda:0')
# epoch 207 lossD tensor(0.0185, device='cuda:0') lossG tensor(11.4534, device='cuda:0')
# epoch 208 lossD tensor(0.0200, device='cuda:0') lossG tensor(7.5139, device='cuda:0')
# epoch 209 lossD tensor(0.0607, device='cuda:0') lossG tensor(8.8215, device='cuda:0')
# epoch 210 lossD tensor(0.4143, device='cuda:0') lossG tensor(7.3466, device='cuda:0')
# epoch 211 lossD tensor(0.1652, device='cuda:0') lossG tensor(5.8387, device='cuda:0')
# epoch 212 lossD tensor(0.0527, device='cuda:0') lossG tensor(8.3289, device='cuda:0')
# epoch 213 lossD tensor(0.0400, device='cuda:0') lossG tensor(6.8112, device='cuda:0')
# epoch 214 lossD tensor(0.0337, device='cuda:0') lossG tensor(7.3487, device='cuda:0')
# epoch 215 lossD tensor(0.0204, device='cuda:0') lossG tensor(7.6639, device='cuda:0')
# epoch 216 lossD tensor(0.0247, device='cuda:0') lossG tensor(8.1946, device='cuda:0')
# epoch 217 lossD tensor(0.0205, device='cuda:0') lossG tensor(7.3268, device='cuda:0')
# epoch 218 lossD tensor(0.1177, device='cuda:0') lossG tensor(8.5484, device='cuda:0')
# epoch 219 lossD tensor(0.0122, device='cuda:0') lossG tensor(9.7541, device='cuda:0')
# epoch 220 lossD tensor(0.1551, device='cuda:0') lossG tensor(6.7324, device='cuda:0')
# epoch 221 lossD tensor(0.0262, device='cuda:0') lossG tensor(7.1486, device='cuda:0')
# epoch 222 lossD tensor(0.0308, device='cuda:0') lossG tensor(7.5864, device='cuda:0')
# epoch 223 lossD tensor(0.0402, device='cuda:0') lossG tensor(8.0220, device='cuda:0')
# epoch 224 lossD tensor(0.0415, device='cuda:0') lossG tensor(8.0931, device='cuda:0')
# epoch 225 lossD tensor(0.0797, device='cuda:0') lossG tensor(5.7383, device='cuda:0')
# epoch 226 lossD tensor(0.0765, device='cuda:0') lossG tensor(6.0540, device='cuda:0')
# epoch 227 lossD tensor(0.1688, device='cuda:0') lossG tensor(5.0203, device='cuda:0')
# epoch 228 lossD tensor(0.0825, device='cuda:0') lossG tensor(7.7460, device='cuda:0')
# epoch 229 lossD tensor(0.0922, device='cuda:0') lossG tensor(5.5916, device='cuda:0')
# epoch 230 lossD tensor(0.0222, device='cuda:0') lossG tensor(7.7564, device='cuda:0')
# epoch 231 lossD tensor(0.0328, device='cuda:0') lossG tensor(7.0546, device='cuda:0')
# epoch 232 lossD tensor(0.0294, device='cuda:0') lossG tensor(7.7351, device='cuda:0')
# epoch 233 lossD tensor(0.3586, device='cuda:0') lossG tensor(6.4873, device='cuda:0')
# epoch 234 lossD tensor(0.1343, device='cuda:0') lossG tensor(7.1110, device='cuda:0')
# epoch 235 lossD tensor(0.0315, device='cuda:0') lossG tensor(7.5046, device='cuda:0')
# epoch 236 lossD tensor(0.0353, device='cuda:0') lossG tensor(7.6178, device='cuda:0')
# epoch 237 lossD tensor(0.0356, device='cuda:0') lossG tensor(7.6893, device='cuda:0')
# epoch 238 lossD tensor(0.0166, device='cuda:0') lossG tensor(8.3224, device='cuda:0')
# epoch 239 lossD tensor(0.0126, device='cuda:0') lossG tensor(8.2615, device='cuda:0')
# epoch 240 lossD tensor(0.0090, device='cuda:0') lossG tensor(7.3454, device='cuda:0')
# epoch 241 lossD tensor(0.0313, device='cuda:0') lossG tensor(7.6679, device='cuda:0')
# epoch 242 lossD tensor(0.0226, device='cuda:0') lossG tensor(7.7200, device='cuda:0')
# epoch 243 lossD tensor(0.0312, device='cuda:0') lossG tensor(8.4392, device='cuda:0')
# epoch 244 lossD tensor(0.0204, device='cuda:0') lossG tensor(9.5039, device='cuda:0')
# epoch 245 lossD tensor(0.3492, device='cuda:0') lossG tensor(8.0157, device='cuda:0')
# epoch 246 lossD tensor(0.1420, device='cuda:0') lossG tensor(6.5787, device='cuda:0')
# epoch 247 lossD tensor(0.0788, device='cuda:0') lossG tensor(7.3576, device='cuda:0')
# epoch 248 lossD tensor(0.0483, device='cuda:0') lossG tensor(7.3503, device='cuda:0')
# epoch 249 lossD tensor(0.0414, device='cuda:0') lossG tensor(7.9346, device='cuda:0')
# epoch 250 lossD tensor(0.0546, device='cuda:0') lossG tensor(6.5379, device='cuda:0')
# epoch 251 lossD tensor(0.0284, device='cuda:0') lossG tensor(7.0622, device='cuda:0')
# epoch 252 lossD tensor(0.0607, device='cuda:0') lossG tensor(7.5655, device='cuda:0')
# epoch 253 lossD tensor(0.1037, device='cuda:0') lossG tensor(5.9167, device='cuda:0')
# epoch 254 lossD tensor(0.0556, device='cuda:0') lossG tensor(6.5313, device='cuda:0')
# epoch 255 lossD tensor(0.0335, device='cuda:0') lossG tensor(7.1234, device='cuda:0')
# epoch 256 lossD tensor(0.0377, device='cuda:0') lossG tensor(6.9566, device='cuda:0')
# epoch 257 lossD tensor(0.0154, device='cuda:0') lossG tensor(8.8092, device='cuda:0')
# epoch 258 lossD tensor(0.0324, device='cuda:0') lossG tensor(7.6796, device='cuda:0')
# epoch 259 lossD tensor(0.0554, device='cuda:0') lossG tensor(8.2669, device='cuda:0')
# epoch 260 lossD tensor(0.0456, device='cuda:0') lossG tensor(7.3279, device='cuda:0')
# epoch 261 lossD tensor(0.0274, device='cuda:0') lossG tensor(9.3487, device='cuda:0')
# epoch 262 lossD tensor(0.0571, device='cuda:0') lossG tensor(8.0295, device='cuda:0')
# epoch 263 lossD tensor(0.0192, device='cuda:0') lossG tensor(8.4279, device='cuda:0')
# epoch 264 lossD tensor(0.1035, device='cuda:0') lossG tensor(9.5335, device='cuda:0')
# epoch 265 lossD tensor(0.0083, device='cuda:0') lossG tensor(8.3546, device='cuda:0')
# epoch 266 lossD tensor(0.0185, device='cuda:0') lossG tensor(8.5746, device='cuda:0')
# epoch 267 lossD tensor(0.7523, device='cuda:0') lossG tensor(5.1608, device='cuda:0')
# epoch 268 lossD tensor(0.1917, device='cuda:0') lossG tensor(5.2801, device='cuda:0')
# epoch 269 lossD tensor(0.1272, device='cuda:0') lossG tensor(6.7571, device='cuda:0')
# epoch 270 lossD tensor(0.0349, device='cuda:0') lossG tensor(8.0422, device='cuda:0')
# epoch 271 lossD tensor(0.0216, device='cuda:0') lossG tensor(8.5880, device='cuda:0')
# epoch 272 lossD tensor(0.0428, device='cuda:0') lossG tensor(7.2186, device='cuda:0')
# epoch 273 lossD tensor(0.0498, device='cuda:0') lossG tensor(7.0122, device='cuda:0')
# epoch 274 lossD tensor(0.0380, device='cuda:0') lossG tensor(10.1775, device='cuda:0')
# epoch 275 lossD tensor(0.0293, device='cuda:0') lossG tensor(7.8414, device='cuda:0')
# epoch 276 lossD tensor(0.0105, device='cuda:0') lossG tensor(11.7407, device='cuda:0')
# epoch 277 lossD tensor(0.2518, device='cuda:0') lossG tensor(5.9168, device='cuda:0')
# epoch 278 lossD tensor(0.0534, device='cuda:0') lossG tensor(7.0156, device='cuda:0')
# epoch 279 lossD tensor(0.0552, device='cuda:0') lossG tensor(7.0050, device='cuda:0')
# epoch 280 lossD tensor(0.0329, device='cuda:0') lossG tensor(8.2237, device='cuda:0')
# epoch 281 lossD tensor(0.0250, device='cuda:0') lossG tensor(8.6170, device='cuda:0')
# epoch 282 lossD tensor(0.0422, device='cuda:0') lossG tensor(8.5073, device='cuda:0')
# epoch 283 lossD tensor(0.0446, device='cuda:0') lossG tensor(8.9477, device='cuda:0')
# epoch 284 lossD tensor(0.0108, device='cuda:0') lossG tensor(10.4041, device='cuda:0')
# epoch 285 lossD tensor(0.0312, device='cuda:0') lossG tensor(7.6833, device='cuda:0')
# epoch 286 lossD tensor(0.0489, device='cuda:0') lossG tensor(8.7986, device='cuda:0')
# epoch 287 lossD tensor(0.0273, device='cuda:0') lossG tensor(7.9457, device='cuda:0')
# epoch 288 lossD tensor(0.0153, device='cuda:0') lossG tensor(9.1688, device='cuda:0')
# epoch 289 lossD tensor(0.0256, device='cuda:0') lossG tensor(8.9296, device='cuda:0')
# epoch 290 lossD tensor(0.0290, device='cuda:0') lossG tensor(9.8224, device='cuda:0')
# epoch 291 lossD tensor(0.0258, device='cuda:0') lossG tensor(7.8831, device='cuda:0')
# epoch 292 lossD tensor(0.0179, device='cuda:0') lossG tensor(9.2975, device='cuda:0')
# epoch 293 lossD tensor(0.0251, device='cuda:0') lossG tensor(8.5669, device='cuda:0')
# epoch 294 lossD tensor(0.8823, device='cuda:0') lossG tensor(4.0195, device='cuda:0')
# epoch 295 lossD tensor(0.3356, device='cuda:0') lossG tensor(4.8946, device='cuda:0')
# epoch 296 lossD tensor(0.3494, device='cuda:0') lossG tensor(7.9308, device='cuda:0')
# epoch 297 lossD tensor(0.0739, device='cuda:0') lossG tensor(6.7136, device='cuda:0')
# epoch 298 lossD tensor(0.0561, device='cuda:0') lossG tensor(6.7408, device='cuda:0')
# epoch 299 lossD tensor(0.0331, device='cuda:0') lossG tensor(6.8483, device='cuda:0')
# epoch 300 lossD tensor(0.0458, device='cuda:0') lossG tensor(8.2583, device='cuda:0')
# epoch 301 lossD tensor(0.0291, device='cuda:0') lossG tensor(8.7415, device='cuda:0')
# epoch 302 lossD tensor(0.0182, device='cuda:0') lossG tensor(8.4129, device='cuda:0')
# epoch 303 lossD tensor(0.1903, device='cuda:0') lossG tensor(7.1034, device='cuda:0')
# epoch 304 lossD tensor(0.0356, device='cuda:0') lossG tensor(7.3547, device='cuda:0')
# epoch 305 lossD tensor(0.0542, device='cuda:0') lossG tensor(7.0483, device='cuda:0')
# epoch 306 lossD tensor(0.0395, device='cuda:0') lossG tensor(7.5741, device='cuda:0')
# epoch 307 lossD tensor(0.0792, device='cuda:0') lossG tensor(6.3857, device='cuda:0')
# epoch 308 lossD tensor(0.0313, device='cuda:0') lossG tensor(8.7419, device='cuda:0')
# epoch 309 lossD tensor(0.0332, device='cuda:0') lossG tensor(7.9134, device='cuda:0')
# epoch 310 lossD tensor(0.0212, device='cuda:0') lossG tensor(8.3290, device='cuda:0')
# epoch 311 lossD tensor(0.0124, device='cuda:0') lossG tensor(8.4505, device='cuda:0')
# epoch 312 lossD tensor(0.0208, device='cuda:0') lossG tensor(8.2407, device='cuda:0')
# epoch 313 lossD tensor(0.0331, device='cuda:0') lossG tensor(8.8373, device='cuda:0')
# epoch 314 lossD tensor(0.0167, device='cuda:0') lossG tensor(9.9884, device='cuda:0')
# epoch 315 lossD tensor(0.0077, device='cuda:0') lossG tensor(9.5156, device='cuda:0')
# epoch 316 lossD tensor(0.0239, device='cuda:0') lossG tensor(9.9257, device='cuda:0')
# epoch 317 lossD tensor(0.0332, device='cuda:0') lossG tensor(10.4059, device='cuda:0')
# epoch 318 lossD tensor(0.0102, device='cuda:0') lossG tensor(10.0984, device='cuda:0')
# epoch 319 lossD tensor(0.0217, device='cuda:0') lossG tensor(9.4966, device='cuda:0')
# epoch 320 lossD tensor(1.0894, device='cuda:0') lossG tensor(0.1275, device='cuda:0')
# epoch 321 lossD tensor(0.1125, device='cuda:0') lossG tensor(6.7560, device='cuda:0')
# epoch 322 lossD tensor(0.0659, device='cuda:0') lossG tensor(6.7625, device='cuda:0')
# epoch 323 lossD tensor(0.0502, device='cuda:0') lossG tensor(7.3403, device='cuda:0')
# epoch 324 lossD tensor(0.0438, device='cuda:0') lossG tensor(8.6026, device='cuda:0')
# epoch 325 lossD tensor(0.0206, device='cuda:0') lossG tensor(8.8206, device='cuda:0')
# epoch 326 lossD tensor(0.0162, device='cuda:0') lossG tensor(9.3042, device='cuda:0')
# epoch 327 lossD tensor(0.0524, device='cuda:0') lossG tensor(8.8421, device='cuda:0')
# epoch 328 lossD tensor(0.0326, device='cuda:0') lossG tensor(8.8866, device='cuda:0')
# epoch 329 lossD tensor(0.0135, device='cuda:0') lossG tensor(8.9631, device='cuda:0')
# epoch 330 lossD tensor(0.0240, device='cuda:0') lossG tensor(8.4706, device='cuda:0')
# epoch 331 lossD tensor(0.0087, device='cuda:0') lossG tensor(10.9635, device='cuda:0')
# epoch 332 lossD tensor(0.0088, device='cuda:0') lossG tensor(9.2348, device='cuda:0')
# epoch 333 lossD tensor(0.0109, device='cuda:0') lossG tensor(8.5362, device='cuda:0')
# epoch 334 lossD tensor(0.0131, device='cuda:0') lossG tensor(9.7543, device='cuda:0')
# epoch 335 lossD tensor(0.0071, device='cuda:0') lossG tensor(10.4958, device='cuda:0')
# epoch 336 lossD tensor(0.0153, device='cuda:0') lossG tensor(9.8615, device='cuda:0')
# epoch 337 lossD tensor(0.2007, device='cuda:0') lossG tensor(8.1250, device='cuda:0')
# epoch 338 lossD tensor(0.1420, device='cuda:0') lossG tensor(7.0780, device='cuda:0')
# epoch 339 lossD tensor(0.0297, device='cuda:0') lossG tensor(7.3888, device='cuda:0')
# epoch 340 lossD tensor(0.0446, device='cuda:0') lossG tensor(8.1862, device='cuda:0')
# epoch 341 lossD tensor(0.0302, device='cuda:0') lossG tensor(7.8920, device='cuda:0')
# epoch 342 lossD tensor(0.0818, device='cuda:0') lossG tensor(8.8482, device='cuda:0')
# epoch 343 lossD tensor(0.0244, device='cuda:0') lossG tensor(9.6143, device='cuda:0')
# epoch 344 lossD tensor(0.0291, device='cuda:0') lossG tensor(9.3587, device='cuda:0')
# epoch 345 lossD tensor(0.0469, device='cuda:0') lossG tensor(7.5527, device='cuda:0')
# epoch 346 lossD tensor(0.0264, device='cuda:0') lossG tensor(9.1188, device='cuda:0')
# epoch 347 lossD tensor(0.0181, device='cuda:0') lossG tensor(12.0985, device='cuda:0')
# epoch 348 lossD tensor(0.0855, device='cuda:0') lossG tensor(10.6649, device='cuda:0')
# epoch 349 lossD tensor(0.0241, device='cuda:0') lossG tensor(9.1661, device='cuda:0')
# epoch 350 lossD tensor(0.0104, device='cuda:0') lossG tensor(9.5135, device='cuda:0')
# epoch 351 lossD tensor(0.0045, device='cuda:0') lossG tensor(10.2354, device='cuda:0')
# epoch 352 lossD tensor(0.0266, device='cuda:0') lossG tensor(8.6271, device='cuda:0')
# epoch 353 lossD tensor(0.1112, device='cuda:0') lossG tensor(5.9095, device='cuda:0')
# epoch 354 lossD tensor(0.1700, device='cuda:0') lossG tensor(6.4213, device='cuda:0')
# epoch 355 lossD tensor(0.0628, device='cuda:0') lossG tensor(6.6083, device='cuda:0')
# epoch 356 lossD tensor(0.0688, device='cuda:0') lossG tensor(7.1803, device='cuda:0')
# epoch 357 lossD tensor(0.0472, device='cuda:0') lossG tensor(9.5103, device='cuda:0')
# epoch 358 lossD tensor(0.0282, device='cuda:0') lossG tensor(8.1650, device='cuda:0')
# epoch 359 lossD tensor(0.0176, device='cuda:0') lossG tensor(8.4631, device='cuda:0')
# epoch 360 lossD tensor(0.0194, device='cuda:0') lossG tensor(9.8785, device='cuda:0')
# epoch 361 lossD tensor(0.0181, device='cuda:0') lossG tensor(9.4753, device='cuda:0')
# epoch 362 lossD tensor(0.0124, device='cuda:0') lossG tensor(7.1231, device='cuda:0')
# epoch 363 lossD tensor(0.0363, device='cuda:0') lossG tensor(8.6695, device='cuda:0')
# epoch 364 lossD tensor(0.0210, device='cuda:0') lossG tensor(9.9427, device='cuda:0')
# epoch 365 lossD tensor(0.0884, device='cuda:0') lossG tensor(11.3772, device='cuda:0')
# epoch 366 lossD tensor(0.0155, device='cuda:0') lossG tensor(10.1688, device='cuda:0')
# epoch 367 lossD tensor(0.0152, device='cuda:0') lossG tensor(10.1469, device='cuda:0')
# epoch 368 lossD tensor(0.0176, device='cuda:0') lossG tensor(9.6778, device='cuda:0')
# epoch 369 lossD tensor(0.0133, device='cuda:0') lossG tensor(10.7932, device='cuda:0')
# epoch 370 lossD tensor(0.0867, device='cuda:0') lossG tensor(14.6860, device='cuda:0')
# epoch 371 lossD tensor(0.1451, device='cuda:0') lossG tensor(7.4947, device='cuda:0')
# epoch 372 lossD tensor(0.0833, device='cuda:0') lossG tensor(8.2231, device='cuda:0')
# epoch 373 lossD tensor(0.0540, device='cuda:0') lossG tensor(7.6504, device='cuda:0')
# epoch 374 lossD tensor(0.0389, device='cuda:0') lossG tensor(8.7340, device='cuda:0')
# epoch 375 lossD tensor(0.0293, device='cuda:0') lossG tensor(7.9766, device='cuda:0')
# epoch 376 lossD tensor(0.0184, device='cuda:0') lossG tensor(9.4696, device='cuda:0')
# epoch 377 lossD tensor(0.0271, device='cuda:0') lossG tensor(8.4743, device='cuda:0')
# epoch 378 lossD tensor(0.0302, device='cuda:0') lossG tensor(9.2209, device='cuda:0')
# epoch 379 lossD tensor(0.0070, device='cuda:0') lossG tensor(9.9356, device='cuda:0')
# epoch 380 lossD tensor(0.0343, device='cuda:0') lossG tensor(8.7252, device='cuda:0')
# epoch 381 lossD tensor(0.0455, device='cuda:0') lossG tensor(7.9336, device='cuda:0')
# epoch 382 lossD tensor(0.0181, device='cuda:0') lossG tensor(9.3777, device='cuda:0')
# epoch 383 lossD tensor(0.0042, device='cuda:0') lossG tensor(10.1841, device='cuda:0')
# epoch 384 lossD tensor(0.0134, device='cuda:0') lossG tensor(8.9112, device='cuda:0')
# epoch 385 lossD tensor(0.0155, device='cuda:0') lossG tensor(9.6346, device='cuda:0')
# epoch 386 lossD tensor(0.0135, device='cuda:0') lossG tensor(10.2069, device='cuda:0')
# epoch 387 lossD tensor(0.0376, device='cuda:0') lossG tensor(11.7338, device='cuda:0')
# epoch 388 lossD tensor(0.0096, device='cuda:0') lossG tensor(10.1992, device='cuda:0')
# epoch 389 lossD tensor(0.0047, device='cuda:0') lossG tensor(10.9341, device='cuda:0')
# epoch 390 lossD tensor(0.0022, device='cuda:0') lossG tensor(11.2912, device='cuda:0')
# epoch 391 lossD tensor(0.0292, device='cuda:0') lossG tensor(10.3212, device='cuda:0')
# epoch 392 lossD tensor(0.0178, device='cuda:0') lossG tensor(11.2727, device='cuda:0')
# epoch 393 lossD tensor(0.0077, device='cuda:0') lossG tensor(8.5414, device='cuda:0')
# epoch 394 lossD tensor(0.0146, device='cuda:0') lossG tensor(12.1884, device='cuda:0')
# epoch 395 lossD tensor(27.6310, device='cuda:0') lossG tensor(0., device='cuda:0')
# epoch 396 lossD tensor(27.6310, device='cuda:0') lossG tensor(0., device='cuda:0')
# epoch 397 lossD tensor(27.6310, device='cuda:0') lossG tensor(0., device='cuda:0')
# epoch 398 lossD tensor(27.6310, device='cuda:0') lossG tensor(0., device='cuda:0')
# epoch 399 lossD tensor(27.6310, device='cuda:0') lossG tensor(0., device='cuda:0')
# Elapsed Time : 6979.332 sec

# %%
n = get_noise(1,100)
image = G(torch.from_numpy(n).cuda().float())

plt.imshow(image.data.cpu().numpy().reshape(28,28))

# %%
image = G(torch.from_numpy(get_noise(10, n_noise)).to(device).float())
fig, ax = plt.subplots(1, 10, figsize=(15,4))
for i in range(10):
    data = image[i].cpu().data.numpy().reshape(3, 96, 96)
    data = np.transpose(data, (1,2,0))
    ax[i].set_axis_off()
    ax[i].imshow(data)

# %%
import tensorflow as tf
import numpy as np

# %%
tf.set_random_seed(777)

idx2char = ['h', 'i', 'e', 'l', 'o']

x_data = [[0, 1, 0, 2, 3, 3]]   # hihell
x_one_hot = [[[1, 0, 0, 0, 0],   # h 0
              [0, 1, 0, 0, 0],   # i 1
              [1, 0, 0, 0, 0],   # h 0
              [0, 0, 1, 0, 0],   # e 2
              [0, 0, 0, 1, 0],   # l 3
              [0, 0, 0, 1, 0]]]  # l 3

y_data = [[1, 0, 2, 3, 3, 4]]

# %%
hidden_size = 5
input_dim = 5
batch_size = 1
sequence_length = 6
learning_rate = 0.1

# %%
X = tf.placeholder(
    tf.float32, [None, sequence_length, input_dim])  # X one-hot
Y = tf.placeholder(tf.int32, [None, sequence_length])  # Y label

# %%
cell = tf.contrib.rnn.BasicLSTMCell(num_units=hidden_size)
initial_state = cell.zero_state(batch_size, tf.float32)
outputs, _states = tf.nn.dynamic_rnn(cell, X, initial_state=initial_state, dtype = tf.float32)

# %%
weights = tf.ones([batch_size, sequence_length])
sequence_loss = tf.contrib.seq2seq.sequence_loss(logits=outputs, targets=Y, weights=weights)

# %%
loss = tf.reduce_mean(sequence_loss)
train = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(loss)

# %%
prediction = tf.argmax(outputs, axis = 2)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(2000):
        l, _ = sess.run([loss, train], feed_dict={X:x_one_hot, Y: y_data})
        result = sess.run(prediction, feed_dict={X:x_one_hot})
        print(i, "loss : ", l, "prediction : ", result, "true Y : ", y_data)
        
        result_str = [idx2char[c] for c in np.squeeze(result)]
        print("\tPrediction str : ", ''.join(result_str))
# Out:
# 0 loss :  1.6077583 prediction :  [[4 3 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  olelll
# 1 loss :  1.5135994 prediction :  [[2 3 3 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  elllll
# 2 loss :  1.4298668 prediction :  [[2 3 3 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  elllll
# 3 loss :  1.3616203 prediction :  [[2 3 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  elelll
# 4 loss :  1.3049464 prediction :  [[2 3 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  elelll
# 5 loss :  1.2577978 prediction :  [[2 2 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  eeelll
# 6 loss :  1.2186247 prediction :  [[2 2 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  eeelll
# 7 loss :  1.1862128 prediction :  [[2 2 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  eeelll
# 8 loss :  1.1591657 prediction :  [[2 2 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  eeelll
# 9 loss :  1.135782 prediction :  [[2 2 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  eeelll
# 10 loss :  1.1147003 prediction :  [[2 2 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  eeelll
# 11 loss :  1.0950649 prediction :  [[2 2 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  eeelll
# 12 loss :  1.0764958 prediction :  [[2 2 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  eeelll
# 13 loss :  1.0590917 prediction :  [[2 2 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  eeelll
# 14 loss :  1.043119 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 15 loss :  1.0284961 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 16 loss :  1.0146362 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 17 loss :  1.0010041 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 18 loss :  0.98748225 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 19 loss :  0.97419643 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 20 loss :  0.96133876 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 21 loss :  0.94907606 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 22 loss :  0.93749964 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 23 loss :  0.9266279 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 24 loss :  0.91639155 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 25 loss :  0.9065914 prediction :  [[2 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ehelll
# 26 loss :  0.89690346 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 27 loss :  0.8870055 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 28 loss :  0.87680817 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 29 loss :  0.8665771 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 30 loss :  0.85676837 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 31 loss :  0.84770274 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 32 loss :  0.83939517 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 33 loss :  0.83168906 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 34 loss :  0.8244904 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 35 loss :  0.81780946 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 36 loss :  0.81161654 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 37 loss :  0.8058189 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 38 loss :  0.8004184 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 39 loss :  0.79545087 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 40 loss :  0.7908578 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 41 loss :  0.7865652 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 42 loss :  0.7825928 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 43 loss :  0.77905273 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 44 loss :  0.7760328 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 45 loss :  0.7734415 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 46 loss :  0.7710094 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 47 loss :  0.76852405 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 48 loss :  0.7660365 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 49 loss :  0.76384914 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 50 loss :  0.76225495 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 51 loss :  0.7608155 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 52 loss :  0.7589092 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 53 loss :  0.75711673 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 54 loss :  0.755949 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 55 loss :  0.7548203 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 56 loss :  0.7533835 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 57 loss :  0.75225616 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 58 loss :  0.75160307 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 59 loss :  0.75059724 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 60 loss :  0.7495756 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 61 loss :  0.74902284 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 62 loss :  0.74834144 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 63 loss :  0.747509 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 64 loss :  0.7470414 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 65 loss :  0.74654835 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 66 loss :  0.7458271 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 67 loss :  0.74533004 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 68 loss :  0.74485576 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 69 loss :  0.74423873 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 70 loss :  0.74387014 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 71 loss :  0.74343073 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 72 loss :  0.7428665 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 73 loss :  0.7425541 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 74 loss :  0.74209106 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 75 loss :  0.74185216 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 76 loss :  0.74148625 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 77 loss :  0.7412364 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 78 loss :  0.74096674 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 79 loss :  0.74076915 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 80 loss :  0.74054337 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 81 loss :  0.74037594 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 82 loss :  0.74017113 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 83 loss :  0.74005693 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 84 loss :  0.7398561 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 85 loss :  0.7397701 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 86 loss :  0.73958325 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 87 loss :  0.7395074 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 88 loss :  0.73935 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 89 loss :  0.73925316 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 90 loss :  0.7391464 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 91 loss :  0.73901856 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 92 loss :  0.73894584 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 93 loss :  0.73881376 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 94 loss :  0.73873395 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 95 loss :  0.738634 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 96 loss :  0.7385243 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 97 loss :  0.73845094 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 98 loss :  0.7383401 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 99 loss :  0.73825157 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 100 loss :  0.73816836 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 101 loss :  0.73806095 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 102 loss :  0.7379792 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 103 loss :  0.7378885 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 104 loss :  0.7377857 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 105 loss :  0.73770285 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 106 loss :  0.7376088 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 107 loss :  0.73750705 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 108 loss :  0.7374201 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 109 loss :  0.73732424 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 110 loss :  0.73722064 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 111 loss :  0.7371273 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 112 loss :  0.73702943 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 113 loss :  0.73692167 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 114 loss :  0.7368195 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 115 loss :  0.7367163 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 116 loss :  0.73660266 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 117 loss :  0.7364876 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 118 loss :  0.7363731 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 119 loss :  0.73624957 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 120 loss :  0.7361175 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 121 loss :  0.7359818 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 122 loss :  0.7358386 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 123 loss :  0.735682 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 124 loss :  0.7355127 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 125 loss :  0.7353314 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 126 loss :  0.7351329 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 127 loss :  0.73491186 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 128 loss :  0.7346662 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 129 loss :  0.7343937 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 130 loss :  0.7340882 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 131 loss :  0.73374367 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 132 loss :  0.7333562 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 133 loss :  0.73292446 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 134 loss :  0.7324488 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 135 loss :  0.731934 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 136 loss :  0.7313938 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 137 loss :  0.7308531 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 138 loss :  0.7303462 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 139 loss :  0.7299108 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 140 loss :  0.7295768 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 141 loss :  0.7293552 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 142 loss :  0.72922873 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 143 loss :  0.72915953 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 144 loss :  0.7291054 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 145 loss :  0.72903746 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 146 loss :  0.7289455 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 147 loss :  0.7288326 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 148 loss :  0.72870606 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 149 loss :  0.7285735 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 150 loss :  0.72843975 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 151 loss :  0.72830856 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 152 loss :  0.7281825 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 153 loss :  0.7280633 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 154 loss :  0.727952 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 155 loss :  0.72784925 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 156 loss :  0.7277546 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 157 loss :  0.72766703 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 158 loss :  0.72758424 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 159 loss :  0.7275028 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 160 loss :  0.72741807 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 161 loss :  0.727324 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 162 loss :  0.7272128 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 163 loss :  0.72707415 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 164 loss :  0.72689545 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 165 loss :  0.726659 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 166 loss :  0.72634804 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 167 loss :  0.72595775 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 168 loss :  0.72551036 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 169 loss :  0.725058 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 170 loss :  0.7246407 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 171 loss :  0.7242722 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 172 loss :  0.7239417 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 173 loss :  0.72362185 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 174 loss :  0.72329605 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 175 loss :  0.72295713 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 176 loss :  0.722593 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 177 loss :  0.72219694 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 178 loss :  0.7217635 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 179 loss :  0.72128856 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 180 loss :  0.720775 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 181 loss :  0.7202293 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 182 loss :  0.7196717 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 183 loss :  0.7191682 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 184 loss :  0.7188058 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 185 loss :  0.71847296 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 186 loss :  0.71763533 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 187 loss :  0.716927 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 188 loss :  0.7167999 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 189 loss :  0.71603054 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 190 loss :  0.71543205 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 191 loss :  0.71514547 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 192 loss :  0.7142469 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 193 loss :  0.7137513 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 194 loss :  0.71296215 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 195 loss :  0.7119533 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 196 loss :  0.71104324 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 197 loss :  0.7097136 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 198 loss :  0.70867383 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 199 loss :  0.70763886 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 200 loss :  0.70671356 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 201 loss :  0.7060859 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 202 loss :  0.7052845 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 203 loss :  0.70463437 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 204 loss :  0.7040007 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 205 loss :  0.7032885 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 206 loss :  0.702763 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 207 loss :  0.7021942 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 208 loss :  0.7017166 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 209 loss :  0.70133895 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 210 loss :  0.700935 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 211 loss :  0.7006563 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 212 loss :  0.70036554 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 213 loss :  0.70010984 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 214 loss :  0.6999153 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 215 loss :  0.6996887 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 216 loss :  0.69952667 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 217 loss :  0.69935644 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 218 loss :  0.6991962 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 219 loss :  0.69906986 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 220 loss :  0.6989225 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 221 loss :  0.69881004 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 222 loss :  0.6986903 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 223 loss :  0.69857574 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 224 loss :  0.69847983 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 225 loss :  0.69837034 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 226 loss :  0.6982815 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 227 loss :  0.6981878 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 228 loss :  0.69809794 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 229 loss :  0.69801843 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 230 loss :  0.69793147 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 231 loss :  0.69785726 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 232 loss :  0.6977792 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 233 loss :  0.697705 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 234 loss :  0.6976361 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 235 loss :  0.69756365 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 236 loss :  0.69749904 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 237 loss :  0.69743216 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 238 loss :  0.6973686 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 239 loss :  0.6973077 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 240 loss :  0.69724554 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 241 loss :  0.6971884 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 242 loss :  0.6971296 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 243 loss :  0.6970739 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 244 loss :  0.6970192 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 245 loss :  0.69696474 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 246 loss :  0.6969132 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 247 loss :  0.6968609 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 248 loss :  0.6968111 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 249 loss :  0.6967616 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 250 loss :  0.696713 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 251 loss :  0.6966661 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 252 loss :  0.696619 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 253 loss :  0.6965737 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 254 loss :  0.6965287 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 255 loss :  0.6964847 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 256 loss :  0.69644153 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 257 loss :  0.6963987 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 258 loss :  0.6963572 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 259 loss :  0.69631577 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 260 loss :  0.6962754 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 261 loss :  0.69623566 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 262 loss :  0.69619626 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 263 loss :  0.6961578 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 264 loss :  0.69611967 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 265 loss :  0.69608223 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 266 loss :  0.6960453 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 267 loss :  0.69600886 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 268 loss :  0.6959731 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 269 loss :  0.6959376 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 270 loss :  0.69590276 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 271 loss :  0.69586825 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 272 loss :  0.69583434 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 273 loss :  0.6958008 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 274 loss :  0.69576764 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 275 loss :  0.695735 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 276 loss :  0.6957028 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 277 loss :  0.69567096 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 278 loss :  0.6956395 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 279 loss :  0.6956084 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 280 loss :  0.6955776 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 281 loss :  0.6955473 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 282 loss :  0.6955174 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 283 loss :  0.6954877 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 284 loss :  0.69545835 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 285 loss :  0.6954293 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 286 loss :  0.6954007 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 287 loss :  0.69537246 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 288 loss :  0.69534445 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 289 loss :  0.6953167 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 290 loss :  0.69528925 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 291 loss :  0.69526213 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 292 loss :  0.69523525 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 293 loss :  0.6952087 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 294 loss :  0.6951825 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 295 loss :  0.69515646 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 296 loss :  0.69513077 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 297 loss :  0.69510525 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 298 loss :  0.69508 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 299 loss :  0.695055 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 300 loss :  0.6950302 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 301 loss :  0.6950058 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 302 loss :  0.6949815 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 303 loss :  0.69495744 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 304 loss :  0.6949336 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 305 loss :  0.69491005 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 306 loss :  0.6948867 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 307 loss :  0.6948635 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 308 loss :  0.69484055 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 309 loss :  0.6948178 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 310 loss :  0.6947953 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 311 loss :  0.6947729 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 312 loss :  0.6947508 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 313 loss :  0.69472885 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 314 loss :  0.6947071 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 315 loss :  0.69468546 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 316 loss :  0.6946642 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 317 loss :  0.69464296 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 318 loss :  0.694622 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 319 loss :  0.69460106 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 320 loss :  0.69458044 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 321 loss :  0.69455993 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 322 loss :  0.69453967 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 323 loss :  0.6945194 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 324 loss :  0.69449943 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 325 loss :  0.69447964 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 326 loss :  0.6944599 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 327 loss :  0.6944403 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 328 loss :  0.694421 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 329 loss :  0.69440174 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 330 loss :  0.69438267 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 331 loss :  0.6943638 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 332 loss :  0.69434494 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 333 loss :  0.6943263 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 334 loss :  0.6943078 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 335 loss :  0.6942894 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 336 loss :  0.6942712 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 337 loss :  0.69425315 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 338 loss :  0.6942351 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 339 loss :  0.6942173 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 340 loss :  0.69419956 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 341 loss :  0.6941819 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 342 loss :  0.6941645 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 343 loss :  0.6941472 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 344 loss :  0.69412994 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 345 loss :  0.69411296 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 346 loss :  0.69409597 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 347 loss :  0.69407904 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 348 loss :  0.6940624 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 349 loss :  0.6940457 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 350 loss :  0.6940292 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 351 loss :  0.6940128 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 352 loss :  0.6939964 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 353 loss :  0.6939802 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 354 loss :  0.6939642 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 355 loss :  0.69394827 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 356 loss :  0.6939324 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 357 loss :  0.6939167 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 358 loss :  0.69390094 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 359 loss :  0.6938853 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 360 loss :  0.69386995 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 361 loss :  0.6938546 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 362 loss :  0.69383925 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 363 loss :  0.693824 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 364 loss :  0.69380903 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 365 loss :  0.693794 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 366 loss :  0.6937791 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 367 loss :  0.6937644 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 368 loss :  0.6937496 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 369 loss :  0.693735 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 370 loss :  0.69372046 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 371 loss :  0.693706 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 372 loss :  0.6936916 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 373 loss :  0.6936773 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 374 loss :  0.6936631 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 375 loss :  0.693649 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 376 loss :  0.6936349 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 377 loss :  0.69362086 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 378 loss :  0.6936071 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 379 loss :  0.69359326 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 380 loss :  0.69357955 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 381 loss :  0.69356585 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 382 loss :  0.6935524 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 383 loss :  0.6935388 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 384 loss :  0.69352543 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 385 loss :  0.69351196 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 386 loss :  0.6934988 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 387 loss :  0.69348544 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 388 loss :  0.6934724 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 389 loss :  0.6934594 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 390 loss :  0.6934463 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 391 loss :  0.6934333 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 392 loss :  0.6934205 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 393 loss :  0.69340765 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 394 loss :  0.6933949 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 395 loss :  0.69338226 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 396 loss :  0.6933696 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 397 loss :  0.693357 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 398 loss :  0.6933446 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 399 loss :  0.69333214 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 400 loss :  0.6933198 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 401 loss :  0.6933075 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 402 loss :  0.69329524 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 403 loss :  0.69328296 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 404 loss :  0.69327086 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 405 loss :  0.69325876 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 406 loss :  0.6932467 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 407 loss :  0.6932348 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 408 loss :  0.6932229 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 409 loss :  0.69321096 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 410 loss :  0.69319916 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 411 loss :  0.6931874 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 412 loss :  0.6931757 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 413 loss :  0.69316405 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 414 loss :  0.69315237 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 415 loss :  0.69314086 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 416 loss :  0.69312924 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 417 loss :  0.6931178 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 418 loss :  0.69310635 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 419 loss :  0.69309497 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 420 loss :  0.69308364 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 421 loss :  0.6930723 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 422 loss :  0.69306105 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 423 loss :  0.69304985 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 424 loss :  0.6930387 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 425 loss :  0.6930275 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 426 loss :  0.6930164 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 427 loss :  0.69300526 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 428 loss :  0.6929943 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 429 loss :  0.6929833 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 430 loss :  0.69297236 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 431 loss :  0.6929614 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 432 loss :  0.6929505 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 433 loss :  0.69293964 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 434 loss :  0.69292873 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 435 loss :  0.69291794 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 436 loss :  0.6929071 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 437 loss :  0.6928963 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 438 loss :  0.6928856 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihelll
# 439 loss :  0.6928749 prediction :  [[1 0 2 3 3 3]] true Y :  [[1, 0, 2, 3, 3, 4]]
# ...
# 1855 loss :  0.63478357 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1856 loss :  0.6347817 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1857 loss :  0.6347798 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1858 loss :  0.6347779 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1859 loss :  0.634776 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1860 loss :  0.6347741 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1861 loss :  0.63477224 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1862 loss :  0.6347704 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1863 loss :  0.6347685 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1864 loss :  0.6347667 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1865 loss :  0.63476473 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1866 loss :  0.6347629 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1867 loss :  0.63476104 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1868 loss :  0.6347592 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1869 loss :  0.6347573 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1870 loss :  0.6347554 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1871 loss :  0.6347536 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1872 loss :  0.6347517 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1873 loss :  0.6347498 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1874 loss :  0.634748 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1875 loss :  0.6347461 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1876 loss :  0.63474417 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1877 loss :  0.6347424 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1878 loss :  0.63474053 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1879 loss :  0.6347387 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1880 loss :  0.6347368 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1881 loss :  0.6347349 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1882 loss :  0.6347331 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1883 loss :  0.6347313 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1884 loss :  0.6347294 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1885 loss :  0.63472754 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1886 loss :  0.63472575 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1887 loss :  0.63472384 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1888 loss :  0.634722 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1889 loss :  0.63472015 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1890 loss :  0.6347183 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1891 loss :  0.6347165 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1892 loss :  0.6347146 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1893 loss :  0.6347128 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1894 loss :  0.63471097 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1895 loss :  0.6347091 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1896 loss :  0.6347073 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1897 loss :  0.6347054 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1898 loss :  0.6347036 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1899 loss :  0.6347018 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1900 loss :  0.63469994 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1901 loss :  0.63469815 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1902 loss :  0.63469625 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1903 loss :  0.63469446 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1904 loss :  0.63469267 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1905 loss :  0.6346908 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1906 loss :  0.63468903 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1907 loss :  0.6346872 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1908 loss :  0.6346853 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1909 loss :  0.63468355 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1910 loss :  0.6346817 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1911 loss :  0.63468 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1912 loss :  0.6346781 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1913 loss :  0.63467634 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1914 loss :  0.6346745 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1915 loss :  0.63467264 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1916 loss :  0.63467085 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1917 loss :  0.63466907 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1918 loss :  0.6346673 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1919 loss :  0.6346654 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1920 loss :  0.6346636 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1921 loss :  0.6346618 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1922 loss :  0.63466 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1923 loss :  0.6346582 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1924 loss :  0.63465637 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1925 loss :  0.63465464 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1926 loss :  0.6346528 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1927 loss :  0.63465106 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1928 loss :  0.6346492 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1929 loss :  0.6346474 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1930 loss :  0.63464564 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1931 loss :  0.6346438 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1932 loss :  0.63464206 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1933 loss :  0.6346402 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1934 loss :  0.63463855 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1935 loss :  0.6346367 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1936 loss :  0.6346349 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1937 loss :  0.6346331 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1938 loss :  0.63463134 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1939 loss :  0.6346295 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1940 loss :  0.63462776 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1941 loss :  0.63462603 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1942 loss :  0.6346242 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1943 loss :  0.63462234 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1944 loss :  0.63462055 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1945 loss :  0.6346189 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1946 loss :  0.6346171 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1947 loss :  0.6346153 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1948 loss :  0.6346135 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1949 loss :  0.6346118 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1950 loss :  0.63461 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1951 loss :  0.6346082 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1952 loss :  0.6346065 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1953 loss :  0.6346047 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1954 loss :  0.63460296 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1955 loss :  0.6346011 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1956 loss :  0.6345994 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1957 loss :  0.63459754 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1958 loss :  0.6345959 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1959 loss :  0.6345941 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1960 loss :  0.6345923 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1961 loss :  0.6345906 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1962 loss :  0.63458884 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1963 loss :  0.6345871 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1964 loss :  0.6345854 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1965 loss :  0.6345836 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1966 loss :  0.6345818 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1967 loss :  0.63458 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1968 loss :  0.6345783 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1969 loss :  0.63457656 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1970 loss :  0.6345748 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1971 loss :  0.63457304 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1972 loss :  0.6345713 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1973 loss :  0.63456964 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1974 loss :  0.63456786 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1975 loss :  0.63456607 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1976 loss :  0.63456434 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1977 loss :  0.6345626 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1978 loss :  0.6345609 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1979 loss :  0.63455915 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1980 loss :  0.63455737 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1981 loss :  0.6345557 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1982 loss :  0.6345539 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1983 loss :  0.6345522 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1984 loss :  0.63455045 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1985 loss :  0.63454866 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1986 loss :  0.634547 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1987 loss :  0.63454527 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1988 loss :  0.6345436 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1989 loss :  0.63454187 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1990 loss :  0.6345401 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1991 loss :  0.63453835 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1992 loss :  0.6345366 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1993 loss :  0.63453496 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1994 loss :  0.63453317 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1995 loss :  0.63453144 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1996 loss :  0.63452977 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1997 loss :  0.63452804 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1998 loss :  0.6345264 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello
# 1999 loss :  0.6345246 prediction :  [[1 0 2 3 3 4]] true Y :  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str :  ihello

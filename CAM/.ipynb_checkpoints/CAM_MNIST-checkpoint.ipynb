# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import datasets, transforms
import torchvision.models as models
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

import PIL
import matplotlib.pyplot as plt
import numpy as np
import time
import cv2
import os

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
trainset = datasets.MNIST(root='../../datasets/MNIST', train=True, download=True, transform=transform)
train_loader = DataLoader(trainset, batch_size=100, shuffle=True)

# %%
testset = datasets.MNIST(root='../../datasets/MNIST', train=False, download=True, transform=transform)
test_loader = DataLoader(testset, batch_size=100, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv = nn.Sequential(
            # 1 x 28 x 28
            nn.Conv2d(1, 16, 3, 1, 1),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            nn.MaxPool2d(2, 2),
            
            # 16 x 14 x 14
            nn.Conv2d(16, 32, 3, 1, 1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.MaxPool2d(2, 2),
            
            # 32 x 7 x 7
            nn.Conv2d(32, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2)

            # output ==> 64 x 7 x 7
        )
        
        # 64 x 7 x 7
        # average pooling으로 인해 accuracy가 낮아짐 -> CNN을 좀 더 깊게 만들어보자
        self.avg_pool = nn.AvgPool2d(7)
        
        # 64 x 1 x 1
        self.fc = nn.Linear(64, 10)
        
    def forward(self, x):
        features = self.conv(x)
        flatten = self.avg_pool(features).view(-1, 64)
#         flatten = features.view(features.size(0), -1)
        output = self.fc(flatten)
        
        return output, features
    
model = Net().cuda()
torch.backends.cudnn.benchmark=True

criterion = nn.CrossEntropyLoss().cuda()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
start = time.time()
print('\n ==> Training Start')

epochs = 10
for epoch in range(epochs):
    total_loss =  0.0
    
#     for data, target in train_loader:
    for data, target in train_loader:
        train_x, train_y = Variable(data.reshape(-1, 1, 28, 28).float()).cuda(), Variable(target.long()).cuda()
        optimizer.zero_grad()
        outputs, f = model(train_x)
        loss = criterion(outputs, train_y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        
    print('\n epoch %d' % (epoch+1), total_loss)
end = time.time()

print('Elapsed Time : %.3f' % (end-start))
# Out:
#  ==> Training Start
#
#  epoch 1 153.48330846056342
#
#  epoch 2 49.16134790610522
#
#  epoch 3 35.82809230638668
#
#  epoch 4 30.067888349294662
#
#  epoch 5 25.79271762049757
#
#  epoch 6 23.693062592297792
#
#  epoch 7 19.710672325105406
#
#  epoch 8 19.478915794403292
#
#  epoch 9 16.768332863925025
#
#  epoch 10 16.487321762775537
# Elapsed Time : 115.200

# %%
def imshow(img):
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(npimg)


# dataiter = iter(test_loader)
# images, labels = dataiter.next()

# imshow(torchvision.utils.make_grid(images))

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    model.eval()
    for data in test_loader:
        images, labels = data
        images = images.cuda()
        labels = labels.cuda()
        outputs, f = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(100):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        i, 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of     0 : 96 %
# Accuracy of     1 : 98 %
# Accuracy of     2 : 99 %
# Accuracy of     3 : 99 %
# Accuracy of     4 : 91 %
# Accuracy of     5 : 98 %
# Accuracy of     6 : 98 %
# Accuracy of     7 : 98 %
# Accuracy of     8 : 98 %
# Accuracy of     9 : 98 %

# %%
import skimage.transform

params = list(model.parameters())

num = 0

for num in range(64):
    print("Predict :",int(predicted[num]),"\t Ans :",int(labels[num]))
    
    overlay = params[-2][int(predicted[num])].matmul(f[num].reshape(64,49)).reshape(7, 7).cpu().data.numpy()

    overlay = overlay - np.min(overlay)
    overlay = overlay / np.max(overlay)
    
    images = images.reshape(-1, 28,28)
    imshow(images[num].cpu())
    skimage.transform.resize(overlay, [28,28])
    plt.imshow(skimage.transform.resize(overlay, [28, 28]), alpha=0.6,cmap='jet')
    plt.show()
    imshow(images[num].cpu())
    plt.show()
# Out:
# Predict : 3 	 Ans : 3
# Predict : 4 	 Ans : 4
# Predict : 2 	 Ans : 2
# Predict : 6 	 Ans : 6
# Predict : 1 	 Ans : 1
# Predict : 4 	 Ans : 4
# Predict : 5 	 Ans : 5
# Predict : 5 	 Ans : 9
# Predict : 4 	 Ans : 4
# Predict : 7 	 Ans : 7
# Predict : 7 	 Ans : 7
# Predict : 6 	 Ans : 6
# Predict : 6 	 Ans : 6
# Predict : 3 	 Ans : 3
# Predict : 6 	 Ans : 6
# Predict : 7 	 Ans : 7
# Predict : 6 	 Ans : 6
# Predict : 8 	 Ans : 8
# Predict : 7 	 Ans : 7
# Predict : 4 	 Ans : 4
# Predict : 2 	 Ans : 2
# Predict : 3 	 Ans : 3
# Predict : 4 	 Ans : 4
# Predict : 8 	 Ans : 8
# Predict : 3 	 Ans : 3
# Predict : 1 	 Ans : 1
# Predict : 6 	 Ans : 6
# Predict : 9 	 Ans : 9
# Predict : 0 	 Ans : 0
# Predict : 7 	 Ans : 7
# Predict : 7 	 Ans : 7
# Predict : 0 	 Ans : 0
# Predict : 2 	 Ans : 2
# Predict : 7 	 Ans : 7
# Predict : 5 	 Ans : 5
# Predict : 3 	 Ans : 3
# Predict : 3 	 Ans : 3
# Predict : 0 	 Ans : 0
# Predict : 3 	 Ans : 3
# Predict : 7 	 Ans : 2
# Predict : 8 	 Ans : 8
# ...

# %%
plt.imshow(np.transpose(images[num], (1, 2 ,0)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-f1d97fb03c75> in <module>
# ----> 1 plt.imshow(np.transpose(images[num], (1, 2 ,0)))
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2700         resample=resample, url=url, **({"data": data} if data is not
# -> 2701         None else {}), **kwargs)
#    2702     sci(__ret)
#    2703     return __ret
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...

# %%
plt.imshow(np.transpose(images[num], (1, 2 ,0)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-f1d97fb03c75> in <module>
# ----> 1 plt.imshow(np.transpose(images[num], (1, 2 ,0)))
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2700         resample=resample, url=url, **({"data": data} if data is not
# -> 2701         None else {}), **kwargs)
#    2702     sci(__ret)
#    2703     return __ret
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...

# %%
correct = 0
total = 0
count = 0
with torch.no_grad():
    model.eval()
    for data, target in test_loader:
        count +=1
        test_x, test_y = Variable(data.reshape(-1, 1, 28, 28).float()).cuda(), Variable(target).cuda()
        outputs, _ = model(test_x)
        _, predicted = torch.max(outputs, 1)

        total += test_y.size(0)
        correct += (predicted.cpu() == test_y.cpu()).sum().item()

print('Acc : %.3f' % ((correct/total) * 100))
# Out:
# Acc : 97.940

# %%
final_conv = 'conv'

#hook (원하는 위치의 gradient값)
feature_blobs = []
def hook_feature(module, input, output):
    feature_blobs.append(output.cpu().data.numpy())
    
model._modules.get(final_conv).register_forward_hook(hook_feature)

# %%
params = list(model.parameters())

weight_softmax = np.squeeze(params[-2].cpu().data.numpy())


def returnCAM(feature_conv, weight_softmax, class_idx):
    size_upsample = (28, 28)
    bz, nc, h, w = feature_conv.shape
    output_cam = []
    cam = weight_softmax[class_idx].dot(feature_conv.reshape((nc, h*w)))
    cam = cam.reshape(h, w)
    cam = cam - np.min(cam)
    cam_img = cam / np.max(cam)
    cam_img = np.uint8(255 * cam_img)
    output_cam.append(cv2.resize(cam_img, size_upsample))
    
    return output_cam

# %%
if not os.path.exists('./result'):
    os.mkdir('result/')

test_batch = iter(test_loader)

# %%
image_tensor, image_label = test_batch.next()
image_PIL = transforms.ToPILImage()(image_tensor[0])
image_PIL.save('./result/test.jpg')

image_tensor = Variable(image_tensor).cuda()
logit, _ = model(image_tensor)
h_x = F.softmax(logit, dim=1).data.squeeze()
probs, idx = h_x.sort(0, True)
print(idx[0].item(), probs[0].item())
CAMs = returnCAM(feature_blobs[0], weight_softmax, [idx[0].item()])
# Out:
# 7 0.9999991655349731

# %%
img = cv2.imread('result/test.jpg')
height, width, _ = img.shape
heatmap = cv2.applyColorMap(cv2.resize(CAMs[0], (width, height)), cv2.COLORMAP_JET)
result = heatmap * 1 + img * 0
cv2.imwrite('result/CAM.jpg', result)
# Out:
# True

# %%
img = image_tensor.cpu().numpy().squeeze()
print(img.shape)
plt.imshow(img)
# Out:
# (28, 28)
